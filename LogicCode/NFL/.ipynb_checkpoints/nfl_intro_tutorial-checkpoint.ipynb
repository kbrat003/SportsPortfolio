# %%
# !pip install nfl_data_py
# !pip install pandas
# !pip install matplotlib
# !pip install pillow

# %%
import nfl_data_py as nfl
import pandas as pd
import os
import urllib.request
import matplotlib.pyplot as plt
from matplotlib.offsetbox import AnnotationBbox, OffsetImage
from PIL import Image

# %%
pbp = nfl.import_pbp_data([2021, 2022, 2023])
# Out:
# 2021 done.
# 2022 done.
# 2023 done.
# Downcasting floats.

# %%
offense = pbp[(pbp['pass'] == 1) | (pbp['rush'] == 1)]
offense = offense.dropna(subset = ['epa', 'posteam', 'defteam'])
offense.shape
# Out:
# (111233, 390)

# %%
pass_epa = offense[(pbp['pass'] == 1)].groupby('posteam')['epa'].mean().reset_index().rename(columns = { 'epa' : 'pass_epa' })
pass_epa.sort_values('pass_epa', ascending  = False)
# Out:
# /var/folders/rn/0thfrjj9331_r1tcvd8tkbfc0000gn/T/ipykernel_22151/231016200.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   pass_epa = offense[(pbp['pass'] == 1)].groupby('posteam')['epa'].mean().reset_index().rename(columns = { 'epa' : 'pass_epa' })
#    posteam  pass_epa
# 28      SF  0.207077
# 15      KC  0.206974
# 3      BUF  0.177383
# 8      DAL  0.155193
# 11      GB  0.144420
# 6      CIN  0.117339
# 29      TB  0.109580
# 25     PHI  0.101222
# 10     DET  0.095800
# 16      LA  0.087869
# 19     MIA  0.082491
# 17     LAC  0.079790
# 20     MIN  0.073105
# 27     SEA  0.071353
# 2      BAL  0.043843
# 14     JAX  0.035790
# 18      LV  0.035640
# 22      NO  0.025341
# 30     TEN  0.024524
# 9      DEN  0.012236
# 0      ARI -0.016701
# 1      ATL -0.018861
# 13     IND -0.023026
# 26     PIT -0.029437
# 21      NE -0.038500
# 7      CLE -0.044510
# 31     WAS -0.047988
# 12     HOU -0.049596
# 5      CHI -0.069344
# 23     NYG -0.073833
# 4      CAR -0.131491
# 24     NYJ -0.133231

# %%
rush_epa = offense[(offense['rush'] == 1)].groupby('posteam')['epa'].mean().reset_index().rename(columns = { 'epa' : 'rush_epa' })
rush_epa.sort_values('rush_epa', ascending  = False)
epa = pd.merge(pass_epa, rush_epa, on = 'posteam')
epa
# Out:
#    posteam  pass_epa  rush_epa
# 0      ARI -0.016701 -0.042838
# 1      ATL -0.018861 -0.101245
# 2      BAL  0.043843 -0.002115
# 3      BUF  0.177383 -0.009464
# 4      CAR -0.131491 -0.079517
# 5      CHI -0.069344 -0.047777
# 6      CIN  0.117339 -0.085950
# 7      CLE -0.044510 -0.033899
# 8      DAL  0.155193 -0.045732
# 9      DEN  0.012236 -0.107365
# 10     DET  0.095800 -0.057788
# 11      GB  0.144420 -0.022614
# 12     HOU -0.049596 -0.193901
# 13     IND -0.023026 -0.069780
# 14     JAX  0.035790 -0.120276
# 15      KC  0.206974 -0.064742
# 16      LA  0.087869 -0.088535
# 17     LAC  0.079790 -0.127875
# 18      LV  0.035640 -0.127591
# 19     MIA  0.082491 -0.080960
# 20     MIN  0.073105 -0.130948
# 21      NE -0.038500 -0.070486
# 22      NO  0.025341 -0.122093
# 23     NYG -0.073833 -0.098017
# 24     NYJ -0.133231 -0.119242
# 25     PHI  0.101222  0.040029
# 26     PIT -0.029437 -0.045289
# 27     SEA  0.071353 -0.044381
# 28      SF  0.207077 -0.024374
# 29      TB  0.109580 -0.112227
# 30     TEN  0.024524 -0.077194
# 31     WAS -0.047988 -0.086617

# %%
logos = nfl.import_team_desc()[['team_abbr', 'team_logo_espn']]
logo_paths = []
team_abbr = []

if not os.path.exists('logos'):
    os.makedirs('logos')

for team in range( len(logos)):
    logo_url = logos['team_logo_espn'][team]
    logo_path = f"logos/{logos['team_abbr'][team]}.png"
    urllib.request.urlretrieve(logo_url, logo_path)
    
    # Resize the logo to a fixed size
    img = Image.open(logo_path)
    img = img.resize((50, 50), Image.LANCZOS)  # Resize to 50x50 pixels
    img.save(logo_path)
    
    logo_paths.append(logo_path)
    team_abbr.append(logos['team_abbr'][team])

logo_data = pd.DataFrame({'team_abbr': team_abbr, 'logo_path': logo_paths})

epa_with_logos = pd.merge(epa, logo_data, left_on = 'posteam', right_on = 'team_abbr')

epa_with_logos
# Out:
#    posteam  pass_epa  rush_epa team_abbr      logo_path
# 0      ARI -0.016701 -0.042838       ARI  logos/ARI.png
# 1      ATL -0.018861 -0.101245       ATL  logos/ATL.png
# 2      BAL  0.043843 -0.002115       BAL  logos/BAL.png
# 3      BUF  0.177383 -0.009464       BUF  logos/BUF.png
# 4      CAR -0.131491 -0.079517       CAR  logos/CAR.png
# 5      CHI -0.069344 -0.047777       CHI  logos/CHI.png
# 6      CIN  0.117339 -0.085950       CIN  logos/CIN.png
# 7      CLE -0.044510 -0.033899       CLE  logos/CLE.png
# 8      DAL  0.155193 -0.045732       DAL  logos/DAL.png
# 9      DEN  0.012236 -0.107365       DEN  logos/DEN.png
# 10     DET  0.095800 -0.057788       DET  logos/DET.png
# 11      GB  0.144420 -0.022614        GB   logos/GB.png
# 12     HOU -0.049596 -0.193901       HOU  logos/HOU.png
# 13     IND -0.023026 -0.069780       IND  logos/IND.png
# 14     JAX  0.035790 -0.120276       JAX  logos/JAX.png
# 15      KC  0.206974 -0.064742        KC   logos/KC.png
# 16      LA  0.087869 -0.088535        LA   logos/LA.png
# 17     LAC  0.079790 -0.127875       LAC  logos/LAC.png
# 18      LV  0.035640 -0.127591        LV   logos/LV.png
# 19     MIA  0.082491 -0.080960       MIA  logos/MIA.png
# 20     MIN  0.073105 -0.130948       MIN  logos/MIN.png
# 21      NE -0.038500 -0.070486        NE   logos/NE.png
# 22      NO  0.025341 -0.122093        NO   logos/NO.png
# 23     NYG -0.073833 -0.098017       NYG  logos/NYG.png
# 24     NYJ -0.133231 -0.119242       NYJ  logos/NYJ.png
# 25     PHI  0.101222  0.040029       PHI  logos/PHI.png
# 26     PIT -0.029437 -0.045289       PIT  logos/PIT.png
# 27     SEA  0.071353 -0.044381       SEA  logos/SEA.png
# 28      SF  0.207077 -0.024374        SF   logos/SF.png
# 29      TB  0.109580 -0.112227        TB   logos/TB.png
# 30     TEN  0.024524 -0.077194       TEN  logos/TEN.png
# 31     WAS -0.047988 -0.086617       WAS  logos/WAS.png

# %%
plt.rcParams["figure.figsize"] = [10,7]
plt.rcParams["figure.autolayout"] = True

def getImage(path):
    return OffsetImage(plt.imread(path, format = 'tif'), zoom = 1)

x = epa_with_logos['pass_epa']
y = epa_with_logos['rush_epa']
paths = epa_with_logos['logo_path']

fig, ax = plt.subplots()

for x0, y0, path in zip(x, y, paths):
    ab = AnnotationBbox(getImage(path), (x0, y0), frameon = False)
    ax.add_artist(ab)

plt.xlim(-0.195, 0.295)
plt.ylim(-0.245, 0.145)
plt.title("Rush and Pass EPA, 2022")
plt.xlabel("EPA/Pass")
plt.ylabel("EPA/Rush")
plt.show()
